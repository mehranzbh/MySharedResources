# %%
import pandas as pd
stats = pd.read_csv('E:\Agile\Python Data Science\P4-Demographic-Data.csv')
stats.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
       'IncomeGroup']

# %% [markdown]
# ### Filtering Dataframe

# %%
stats.InternetUsers <5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
Filter1 = stats.InternetUsers <5
Filter1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
stats[Filter1]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 11                    Burundi         BDI     44.151            1.3
# 13                      Benin         BEN     36.440            4.9
# 29   Central African Republic         CAF     34.076            3.5
# 52                    Eritrea         ERI     34.800            0.9
# 55                   Ethiopia         ETH     32.925            1.9
# 64                     Guinea         GIN     37.337            1.6
# 66              Guinea-Bissau         GNB     37.503            3.1
# 99                    Liberia         LBR     35.521            3.2
# 111                Madagascar         MDG     34.686            3.0
# 115                      Mali         MLI     44.138            3.5
# 117                   Myanmar         MMR     18.119            1.6
# 127                     Niger         NER     49.661            1.7
# 154              Sierra Leone         SLE     36.729            1.7
# ...

# %%
Filter2 = stats.BirthRate > 40
stats [Filter2]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %% [markdown]
# ### combining filters

# %%
stats [Filter1 and Filter2 ]        #we should use another operator for boolians in series
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_732/2723909538.py in <module>
# ----> 1 stats [Filter1 and Filter2 ]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
stats [Filter1 & Filter2 ]      # the '&' is used as the 'and' operation for series
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11            Burundi         BDI     44.151            1.3  Low income
# 115              Mali         MLI     44.138            3.5  Low income
# 127             Niger         NER     49.661            1.7  Low income
# 156           Somalia         SOM     43.891            1.5  Low income
# 167              Chad         TCD     45.745            2.3  Low income
# 192  Congo, Dem. Rep.         COD     42.394            2.2  Low income

# %%
stats[stats.IncomeGroup == 'High income']
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                    Aruba         ABW     10.244          78.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 8                Australia         AUS     13.200          83.00  High income
# ..                     ...         ...        ...            ...          ...
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 181          United States         USA     12.500          84.20  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
#
# [67 rows x 5 columns]

# %%
stats[(stats.IncomeGroup == 'High income')&(stats.BirthRate>20)]
# Out:
#            CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 67   Equatorial Guinea         GNQ     35.362          16.40  High income
# 85              Israel         ISR     21.300          70.80  High income
# 96              Kuwait         KWT     20.575          75.46  High income
# 134               Oman         OMN     20.419          66.45  High income
# 149       Saudi Arabia         SAU     20.576          60.50  High income

# %%
stats.IncomeGroup.unique()          #extracting unique values for a column
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
stats.InternetUsers.unique()          #extracting unique values for a column
# Out:
# array([78.9       ,  5.9       , 19.1       , 57.2       , 88.        ,
#        59.9       , 41.9       , 63.4       , 83.        , 80.6188    ,
#        58.7       ,  1.3       , 82.1702    ,  4.9       ,  9.1       ,
#         6.63      , 53.0615    , 90.0000397 , 72.        , 57.79      ,
#        54.17      , 33.6       , 95.3       , 36.94      , 51.04      ,
#        73.        , 64.5       , 29.9       , 15.        ,  3.5       ,
#        85.8       , 86.34      , 66.5       , 45.8       ,  8.4       ,
#         6.4       ,  6.6       , 51.7       ,  6.5       , 37.5       ,
#        45.96      , 27.93      , 74.1       , 65.4548    , 74.1104    ,
#        84.17      ,  9.5       , 94.6297    , 45.9       , 16.5       ,
#        40.35368423, 29.4       ,  0.9       , 71.635     , 79.4       ,
#         1.9       , 91.5144    , 37.1       , 81.9198    , 27.8       ,
#         9.2       , 89.8441    , 43.3       , 12.3       ,  1.6       ,
# ...

# %%
stats[stats.CountryName == 'Malta']         #Accessing a specific row
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 116       Malta         MLT        9.5        68.9138  High income

# %%
stats[stats.CountryName == 'Malta'].BirthRate         #Accessing a specific row
# Out:
# 116    9.5
# Name: BirthRate, dtype: float64
